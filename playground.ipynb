# %% [markdown]
# First we have to load in our data, stored as a .txt file. To protect private company info, the `file_path' variable is loaded separately.

# %%
import re
import pandas as pd
from datetime import datetime, timedelta

execfile("confidential.py")

# Open the file in read mode
with open(file_path, 'r') as file:
    # Read the contents of the file
    file_contents = file.read()

# Now you can use the `file_contents` variable which contains the content of the file
print(file_contents)
# Out:
# ----------------------------------------------------------------------------------------------------
# E2001  Check-In 05:14   Check-Out 13:50            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     2295  EWR  06:14   MIA  09:18   001:07   32M   003:04                 |=====================|
#  1     2594  MIA  10:25   EWR  13:35            32M   003:10                 |         -- -- -- 03 |
#                                                                  008:36      |04 -- -- -- -- -- -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 006:14                                        006:14     008:36      |-- -- -- -- -- -- -- |
# TAFB: 008:36                                                                 |-- -- -- -- -- --    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2002  Check-In 05:59   Check-Out 14:09            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     1711  EWR  06:59   RSW  09:57   001:03   32M   002:58                 |=====================|
#  1     1712  RSW  11:00   EWR  13:54            32M   002:54                 |         -- -- -- -- |
#                                                                  008:10      |-- -- -- 07 08 09 -- |
#                                                     ----------------------   |11 12 -- 14 -- 16 -- |
# Credit: 005:52                                        005:52     008:10      |18 19 20 21 22 23 -- |
# TAFB: 008:10                                                                 |25 26 27 -- 29 30    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2003  Check-In 05:59   Check-Out 14:19            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     1711  EWR  06:59   RSW  09:57   001:13   32M   002:58                 |=====================|
#  1     1712  RSW  11:10   EWR  14:04            32M   002:54                 |         -- -- -- -- |
#                                                                  008:20      |-- -- -- -- -- -- 10 |
#                                                     ----------------------   |-- -- -- -- -- -- 17 |
# Credit: 005:52                                        005:52     008:20      |-- -- -- -- -- -- 24 |
# TAFB: 008:20                                                                 |-- -- -- -- -- --    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2004  Check-In 06:00   Check-Out 14:18            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     2295  EWR  07:00   MIA  10:08   000:45   32M   003:08                 |=====================|
#  1     2594  MIA  10:53   EWR  14:03            32M   003:10                 |         31 01 02 -- |
#                                                                  008:18      |-- -- 06 -- -- -- -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 006:18                                        006:18     008:18      |-- -- -- -- -- -- -- |
# TAFB: 008:18                                                                 |-- -- -- -- -- --    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2005  Check-In 06:12   Check-Out 14:16            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     1711  EWR  07:12   RSW  10:08   000:55   32M   002:56                 |=====================|
#  1     1712  RSW  11:03   EWR  14:01            32M   002:58                 |         -- -- -- -- |
#                                                                  008:04      |-- -- 06 -- -- -- -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 005:54                                        005:54     008:04      |-- -- -- -- -- -- -- |
# TAFB: 008:04                                                                 |-- -- -- -- -- --    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2006  Check-In 06:19   Check-Out 14:16            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     1711  EWR  07:19   RSW  10:15   000:48   32M   002:56                 |=====================|
#  1     1712  RSW  11:03   EWR  14:01            32M   002:58                 |         31 01 02 03 |
#                                                                  007:57      |04 05 -- -- -- -- -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 005:54                                        005:54     007:57      |-- -- -- -- -- -- -- |
# TAFB: 007:57                                                                 |-- -- -- -- -- --    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2007  Check-In 06:20   Check-Out 16:46            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     1229  EWR  07:20   CUN  10:25   001:00   32M   004:05                 |=====================|
#  1     1230  CUN  11:25   EWR  16:31            32M   004:06                 |         31 -- -- -- |
#                                                                  010:26      |-- -- -- -- -- -- -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 008:11                                        008:11     010:26      |-- -- -- -- -- -- -- |
# TAFB: 010:26                                                                 |-- -- -- -- -- --    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2008  Check-In 06:30   Check-Out 16:35            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     1229  EWR  07:30   CUN  10:26   001:00   32M   003:56                 |=====================|
#  1     1230  CUN  11:26   EWR  16:20            32M   003:54                 |         -- -- -- -- |
#                                                                  010:05      |-- -- -- -- -- -- -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 007:50                                        007:50     010:05      |-- 19 -- -- -- -- -- |
# TAFB: 010:05                                                                 |-- -- -- -- -- --    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2009  Check-In 07:00   Check-Out 15:40            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     2117  EWR  08:00   NAS  11:01   001:08   32M   003:01                 |=====================|
#  1     2118  NAS  12:09   EWR  15:25            32M   003:16                 |         -- -- -- 03 |
#                                                                  008:40      |-- -- -- -- -- -- -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 006:17                                        006:17     008:40      |-- -- -- -- -- -- -- |
# TAFB: 008:40                                                                 |-- -- -- -- -- --    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2010  Check-In 07:00   Check-Out 17:15            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     2267  EWR  08:00   POP  11:45   001:15   32M   003:45                 |=====================|
#  1     2226  POP  13:00   EWR  17:00            32M   004:00                 |         -- 01 -- -- |
#                                                                  010:15      |-- -- -- -- -- -- -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 007:45                                        007:45     010:15      |-- -- -- -- -- -- -- |
# TAFB: 010:15                                                                 |-- -- -- -- -- --    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2011  Check-In 08:00   Check-Out 15:55            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     0573  EWR  09:00   TPA  12:00   000:49   32M   003:00                 |=====================|
#  1     2274  TPA  12:49   EWR  15:40            32M   002:51                 |         -- -- -- 03 |
#                                                                  007:55      |-- -- -- -- -- -- -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 005:51                                        005:51     007:55      |-- -- -- -- -- -- -- |
# TAFB: 007:55                                                                 |-- -- -- -- -- --    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2012  Check-In 08:00   Check-Out 18:19            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     1015  EWR  09:00   PUJ  13:01   001:00   32M   004:01                 |=====================|
#  1     1016  PUJ  14:01   EWR  18:04            32M   004:03                 |         -- -- -- -- |
#                                                                  010:19      |-- -- -- -- -- -- -- |
#                                                     ----------------------   |-- 12 -- -- -- -- -- |
# Credit: 008:04                                        008:04     010:19      |-- -- -- -- -- -- -- |
# TAFB: 010:19                                                                 |25 -- -- -- 29 --    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2013  Check-In 08:03   Check-Out 19:25            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1 DH  0345  EWR  08:33   AUA  13:15   001:00   32M   000:00                 |=====================|
#  1     0346  AUA  14:15   EWR  19:10            32M   004:55                 |         -- -- -- -- |
#                                                                  011:22      |-- -- -- -- -- -- -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 009:37                                        004:55     011:22      |-- -- -- -- 22 -- -- |
# TAFB: 011:22                                                                 |-- -- -- -- -- --    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2014  Check-In 08:15   Check-Out 18:34            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     0107  EWR  09:15   MBJ  12:18   001:02   32M   004:03                 |=====================|
#  1     0108  MBJ  13:20   EWR  18:19            32M   003:59                 |         -- 01 -- -- |
#                                                                  010:19      |-- -- -- -- -- -- -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 008:02                                        008:02     010:19      |-- -- -- -- -- -- -- |
# TAFB: 010:19                                                                 |-- -- -- -- -- --    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2015  Check-In 08:20   Check-Out 18:25            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     0107  EWR  09:20   MBJ  12:14   001:00   32M   003:54                 |=====================|
#  1     0108  MBJ  13:14   EWR  18:10            32M   003:56                 |         -- -- -- -- |
#                                                                  010:05      |-- -- -- -- -- -- -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 007:50                                        007:50     010:05      |18 -- -- -- -- -- -- |
# TAFB: 010:05                                                                 |25 -- -- -- -- --    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2016  Check-In 08:53   Check-Out 18:34            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     1527  EWR  09:53   MCO  12:48   002:27   32M   002:55  *              |=====================|
#  1     0028  MCO  15:15   EWR  18:19            32M   003:04                 |         31 -- -- 03 |
#                                                                  009:41      |-- -- -- -- -- -- -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 005:59                                        005:59     009:41      |-- -- -- -- -- -- -- |
# TAFB: 009:41                                                                 |-- -- -- -- -- --    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2017  Check-In 09:48   Check-Out 20:15            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     0107  EWR  10:48   MBJ  13:52   001:10   32M   004:04                 |=====================|
#  1     0108  MBJ  15:02   EWR  20:00            32M   003:58                 |         31 -- -- -- |
#                                                                  010:27      |-- -- -- -- -- -- -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 008:02                                        008:02     010:27      |-- -- -- -- -- -- -- |
# TAFB: 010:27                                                                 |-- -- -- -- -- --    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2018  Check-In 11:40   Check-Out 21:45            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     1215  EWR  12:40   PUJ  16:31   001:00   32M   003:51                 |=====================|
#  1     1216  PUJ  17:31   EWR  21:30            32M   003:59                 |         -- -- -- 03 |
#                                                                  010:05      |-- -- -- -- -- -- -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 007:50                                        007:50     010:05      |-- -- -- -- -- -- -- |
# TAFB: 010:05                                                                 |-- -- -- -- -- --    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2019  Check-In 13:00   Check-Out 20:42            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     0843  EWR  14:00   PBI  16:50   000:45   32M   002:50                 |=====================|
#  1     1244  PBI  17:35   EWR  20:27            32M   002:52                 |         -- -- -- -- |
#                                                                  007:42      |-- -- -- -- -- -- -- |
#                                                     ----------------------   |-- 12 -- -- -- -- -- |
# Credit: 005:42                                        005:42     007:42      |-- -- -- -- -- 23 -- |
# TAFB: 007:42                                                                 |-- -- -- -- -- 30    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2020  Check-In 13:15   Check-Out 20:59            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     1527  EWR  14:15   MCO  16:58   000:57   32M   002:43                 |=====================|
#  1     0494  MCO  17:55   EWR  20:44            32M   002:49                 |         -- -- -- -- |
#                                                                  007:44      |-- -- -- -- 08 09 -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 005:32                                        005:32     007:44      |-- -- -- -- -- -- -- |
# TAFB: 007:44                                                                 |-- -- -- -- -- --    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2021  Check-In 13:45   Check-Out 22:13            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1 DH  1527  EWR  14:15   MCO  16:58   002:17   32M   000:00  *              |=====================|
#  1     0828  MCO  19:15   EWR  21:58            32M   002:43                 |         -- -- -- -- |
#                                                                  008:28      |-- -- -- -- -- -- -- |
#                                                     ----------------------   |-- 12 -- -- -- -- -- |
# Credit: 005:26                                        002:43     008:28      |-- -- -- -- -- -- -- |
# TAFB: 008:28                                                                 |-- -- -- -- -- --    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2022  Check-In 13:49   Check-Out 21:43            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     0843  EWR  14:49   PBI  17:45   000:50   32M   002:56                 |=====================|
#  1     1244  PBI  18:35   EWR  21:28            32M   002:53                 |         -- -- 02 -- |
#                                                                  007:54      |-- -- -- -- -- -- -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 005:49                                        005:49     007:54      |-- -- -- -- -- -- -- |
# TAFB: 007:54                                                                 |-- -- -- -- -- --    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2023  Check-In 13:54   Check-Out 21:43            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     0843  EWR  14:54   PBI  17:50   000:45   32M   002:56                 |=====================|
#  1     1244  PBI  18:35   EWR  21:28            32M   002:53                 |         -- -- -- -- |
#                                                                  007:49      |-- -- 06 -- -- -- -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 005:49                                        005:49     007:49      |-- -- -- -- -- -- -- |
# TAFB: 007:49                                                                 |-- -- -- -- -- --    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2024  Check-In 14:14   Check-Out 23:57            1-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     1493  EWR  15:14   STI  18:59   001:00   32M   003:45                 |=====================|
#  1     0194  STI  19:59   EWR  23:42            32M   003:43                 |         -- -- -- -- |
#                                                                  009:43      |-- -- -- -- -- -- -- |
#                                                     ----------------------   |-- -- -- -- -- 16 -- |
# Credit: 007:28                                        007:28     009:43      |-- -- -- -- 22 23 -- |
# TAFB: 009:43                                                                 |-- -- -- -- -- 30    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2025  Check-In 05:59   Check-Out 23:10            2-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     0483  EWR  06:59   SFO  10:01            32S   006:02                 |=====================|
#    SFO   027:14  Marriott at Fisherman's W     415-775-7555      007:17      |         -- -- -- -- |
#  2     1982  SFO  14:15   EWR  22:55            32S   005:40                 |04 -- -- -- -- -- -- |
#                                                                  006:40      |-- -- -- -- -- -- -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 011:46                                        011:42     013:57      |-- -- -- -- -- --    |
# TAFB: 041:11                                                                 +---------------------+
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2026  Check-In 06:00   Check-Out 20:42            2-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     0927  EWR  07:00   MCO  09:39            32M   002:39                 |=====================|
#    MCO   023:21  Hyatt Regency Orlando         407-284-1234      003:54      |         -- -- -- -- |
#  2     2528  MCO  10:00   EWR  12:37   001:23   32M   002:37                 |-- -- -- -- -- -- -- |
#        0843  EWR  14:00   PBI  16:50   000:45   32M   002:50                 |-- -- -- -- -- -- -- |
#  2     1244  PBI  17:35   EWR  20:27            32M   002:52                 |-- -- -- -- -- -- 24 |
#                                                                  011:27      |-- -- -- -- -- --    |
#                                                     ----------------------   +---------------------+
# Credit: 011:03                                        010:58     015:21
# TAFB: 038:42
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2027  Check-In 06:00   Check-Out 12:52            2-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     0927  EWR  07:00   MCO  09:39   001:31   32M   002:39                 |=====================|
#  1     1033  MCO  11:10   SJU  14:06            32M   002:56                 |         -- -- -- -- |
#    SJU   015:09  Fairmont El San Juan Hote     787-791-1000      008:21      |-- -- -- -- -- -- -- |
#  2     1434  SJU  06:15   MCO  09:12   000:48   32M   002:57                 |-- -- -- -- -- -- -- |
#  2     2528  MCO  10:00   EWR  12:37            32M   002:37                 |-- -- -- -- -- -- -- |
#                                                                  007:22      |-- -- -- -- -- 30    |
#                                                     ----------------------   +---------------------+
# Credit: 011:09                                        011:09     015:43
# TAFB: 030:52
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2028  Check-In 06:00   Check-Out 12:52            2-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     0573  EWR  07:00   TPA  09:46   000:45   32M   002:46                 |=====================|
#        1051  TPA  10:31   SJU  13:29   000:45   32M   002:58                 |         -- -- -- -- |
#        1036  SJU  14:14   STT  14:50   000:45   32M   000:36                 |-- -- -- -- -- 09 -- |
#  1     1135  STT  15:35   SJU  16:13            32M   000:38                 |-- -- -- -- -- -- -- |
#    SJU   013:02  Sheraton Puerto Rico Hote     787 993 3500      010:28      |-- -- -- -- -- -- -- |
#  2     1434  SJU  06:15   MCO  09:12   000:48   32M   002:57                 |-- -- -- -- -- --    |
#  2     2528  MCO  10:00   EWR  12:37            32M   002:37                 +---------------------+
#                                                                  007:22
#                                                     ----------------------
# Credit: 012:32                                        012:32     017:50
# TAFB: 030:52
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2029  Check-In 06:00   Check-Out 22:13            2-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     0573  EWR  07:00   TPA  09:46   000:45   32M   002:46                 |=====================|
#        1051  TPA  10:31   SJU  13:29   000:45   32M   002:58                 |         -- -- -- -- |
#        1036  SJU  14:14   STT  14:50   000:45   32M   000:36                 |-- -- -- -- -- -- -- |
#  1     1135  STT  15:35   SJU  16:13            32M   000:38                 |-- -- -- 14 -- -- -- |
#    SJU   021:12  Royal Sonesta                 787-791-6100      010:28      |-- -- -- -- -- -- -- |
#  2     0934  SJU  14:25   MCO  17:23   001:52   32M   002:58                 |-- -- -- -- -- --    |
#  2     0828  MCO  19:15   EWR  21:58            32M   002:43                 +---------------------+
#                                                                  008:33
#                                                     ----------------------
# Credit: 012:39                                        012:39     019:01
# TAFB: 040:13
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2030  Check-In 06:00   Check-Out 23:10            2-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     1373  EWR  07:00   LAX  09:42   001:06   32S   005:42  *              |=====================|
#  1     2532  LAX  10:48   SLC  13:41            32M   001:53                 |         31 -- -- -- |
#    SLC   020:59  Radisson Hotel Salt Lake      801-531-7500      009:56      |-- -- -- -- -- -- -- |
#  2     0802  SLC  11:40   MCO  18:04   002:06   32M   004:24  *              |-- -- -- -- -- -- -- |
#  2     0828  MCO  20:10   EWR  22:55            32M   002:45                 |-- -- -- -- -- -- -- |
#                                                                  010:15      |-- -- -- -- -- --    |
#                                                     ----------------------   +---------------------+
# Credit: 014:44                                        014:44     020:11
# TAFB: 041:10
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2031  Check-In 06:20   Check-Out 14:18            2-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     1229  EWR  07:20   CUN  10:25   001:00   32M   004:05                 |=====================|
#  1     1230  CUN  11:25   EWR  16:31            32M   004:06                 |         -- -- -- -- |
#    EWR   013:29  Renaissance EWR Airport       908-436-4600      010:26      |04 -- -- -- -- -- -- |
#  2     2295  EWR  07:00   MIA  10:08   000:45   32M   003:08                 |-- -- -- -- -- -- -- |
#  2     2594  MIA  10:53   EWR  14:03            32M   003:10                 |-- -- -- -- -- -- -- |
#                                                                  008:03      |-- -- -- -- -- --    |
#                                                     ----------------------   +---------------------+
# Credit: 014:29                                        014:29     018:29
# TAFB: 031:58
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2032  Check-In 07:29   Check-Out 19:31            2-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     0345  EWR  08:29   AUA  13:15            32M   004:46                 |=====================|
#    AUA   024:00  Renaissance Aruba Resort      011 2975836000    006:01      |         -- -- -- -- |
#  2     0346  AUA  14:15   EWR  19:16            32M   005:01                 |-- 05 -- -- -- -- -- |
#                                                                  006:01      |-- -- -- -- -- -- -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 010:18                                        009:47     012:02      |-- -- -- -- -- --    |
# TAFB: 036:02                                                                 +---------------------+
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2033  Check-In 07:33   Check-Out 19:25            2-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     0345  EWR  08:33   AUA  13:15            32M   004:42                 |=====================|
#    AUA   024:00  Renaissance Aruba Resort      011 2975836000    005:57      |         -- -- -- -- |
#  2     0346  AUA  14:15   EWR  19:10            32M   004:55                 |-- -- -- -- -- -- -- |
#                                                                  005:55      |-- -- -- -- 15 -- -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 010:15                                        009:37     011:52      |-- -- -- -- -- --    |
# TAFB: 035:52                                                                 +---------------------+
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2034  Check-In 08:45   Check-Out 19:54            2-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     1773  EWR  09:45   LAX  12:54            32S   006:09                 |=====================|
#    LAX   021:11  SONESTA REDONDO BEACH & M     310-318-8888      007:24      |         -- -- -- -- |
#  2     1374  LAX  11:05   EWR  19:39            32S   005:34                 |-- -- -- -- -- -- -- |
#                                                                  006:34      |-- -- -- -- -- -- -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 011:43                                        011:43     013:58      |-- -- -- -- 29 --    |
# TAFB: 035:09                                                                 +---------------------+
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2035  Check-In 09:00   Check-Out 22:13            2-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     1589  EWR  10:00   SJU  14:10   002:30   32M   004:10  *              |=====================|
#        0936  SJU  16:40   STT  17:13   000:46   32M   000:33                 |         -- -- -- -- |
#  1     0435  STT  17:59   SJU  18:35            32M   000:36                 |-- -- -- -- -- -- -- |
#    SJU   018:50  Fairmont El San Juan Hote     787-791-1000      009:50      |-- -- -- -- -- -- -- |
#  2     0934  SJU  14:25   MCO  17:23   001:52   32M   002:58                 |-- -- -- 21 -- -- -- |
#  2     0828  MCO  19:15   EWR  21:58            32M   002:43                 |-- -- -- 28 -- --    |
#                                                                  008:33      +---------------------+
#                                                     ----------------------
# Credit: 011:00                                        011:00     018:23
# TAFB: 037:13
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2036  Check-In 09:55   Check-Out 18:19            2-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     0205  EWR  10:55   FLL  13:52   002:48   32M   002:57  *              |=====================|
#        1575  FLL  16:40   KIN  17:25   001:00   32M   001:45                 |         -- -- -- -- |
#  1     1376  KIN  18:25   FLL  21:19            32M   001:54                 |-- -- -- -- -- -- -- |
#    FLL   012:11  Hyatt Place Fort Lauderda     954-922-0436      011:39      |-- -- -- -- -- -- -- |
#  2     0173  FLL  10:30   PUJ  12:55   001:06   32M   002:25                 |-- -- -- -- -- -- -- |
#  2     1016  PUJ  14:01   EWR  18:04            32M   004:03                 |-- -- -- -- 29 --    |
#                                                                  008:34      +---------------------+
#                                                     ----------------------
# Credit: 013:04                                        013:04     020:13
# TAFB: 032:24
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2037  Check-In 14:55   Check-Out 23:10            2-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     0683  EWR  15:55   SFO  19:27            32S   006:32                 |=====================|
#    SFO   017:48  The Westin St. Francis Sa     415-397-7000      007:47      |         -- 01 -- -- |
#  2     1982  SFO  14:15   EWR  22:55            32S   005:40                 |-- -- -- -- -- -- -- |
#                                                                  006:40      |-- -- -- -- -- -- -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 012:12                                        012:12     014:27      |-- -- -- -- -- --    |
# TAFB: 032:15                                                                 +---------------------+
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2038  Check-In 15:50   Check-Out 23:10            2-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     1727  EWR  16:50   MCO  19:49   002:08   32M   002:59  *              |=====================|
#  1     0284  MCO  21:57   JFK  00:30            321   002:33                 |         -- -- 02 -- |
#    JFK   012:55  Hilton JFK                    718-659-0200      008:55      |-- -- -- -- -- -- -- |
#  2     0383  JFK  14:25   MCO  17:24   002:46   321   002:59  *              |-- -- -- -- -- -- -- |
#  2     0828  MCO  20:10   EWR  22:55            32M   002:45                 |-- -- -- -- -- -- -- |
#                                                                  009:30      |-- -- -- -- -- --    |
#                                                     ----------------------   +---------------------+
# Credit: 011:16                                        011:16     018:25
# TAFB: 031:20
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2039  Check-In 17:15   Check-Out 19:54            2-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     2073  EWR  18:15   LAX  21:18            32S   006:03                 |=====================|
#    LAX   012:47  Aloft El Segundo              424-290-5555      007:18      |         -- -- -- -- |
#  2     1374  LAX  11:05   EWR  19:39            32S   005:34                 |-- -- -- -- -- -- -- |
#                                                                  006:34      |-- -- -- -- -- -- -- |
#                                                     ----------------------   |-- -- -- 21 -- -- -- |
# Credit: 011:37                                        011:37     013:52      |-- -- -- -- -- --    |
# TAFB: 026:39                                                                 +---------------------+
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2040  Check-In 19:15   Check-Out 05:19            2-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     0593  EWR  20:15   STI  23:58   001:22   32M   003:43                 |=====================|
#  2     0594  STI  01:20   EWR  05:04            32M   003:44                 |         31 01 02 03 |
#                                                                  010:04      |04 05 -- -- -- -- -- |
#                                                     ----------------------   |-- -- -- -- -- -- -- |
# Credit: 007:27                                        007:27     010:04      |-- -- -- -- -- -- -- |
# TAFB: 010:04                                                                 |-- -- -- -- -- --    |
# Crew Comp:  1 CA, 1 FO                                                       +---------------------+
# ----------------------------------------------------------------------------------------------------
# E2041  Check-In 06:00   Check-Out 14:09            3-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     0927  EWR  07:00   MCO  09:39   001:31   32M   002:39                 |=====================|
#  1     1033  MCO  11:10   SJU  14:06            32M   002:56                 |         -- -- -- -- |
#    SJU   015:09  Fairmont El San Juan Hote     787-791-1000      008:21      |-- -- -- -- -- -- -- |
#  2     1434  SJU  06:15   MCO  09:12   000:48   32M   002:57                 |11 -- -- -- -- -- -- |
#  2     2528  MCO  10:00   EWR  12:37            32M   002:37                 |-- -- -- -- -- -- -- |
#    EWR   017:22  The Westin Jersey City Ne     201-626-2900      007:22      |-- -- -- -- -- --    |
#  3     1711  EWR  06:59   RSW  09:57   001:03   32M   002:58                 +---------------------+
#  3     1712  RSW  11:00   EWR  13:54            32M   002:54
#                                                                  007:55
#                                                     ----------------------
# Credit: 017:01                                        017:01     023:38
# TAFB: 056:09
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2042  Check-In 06:00   Check-Out 12:52            3-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     0927  EWR  07:00   MCO  09:39   001:31   32M   002:39                 |=====================|
#  1     1033  MCO  11:10   SJU  14:06            32M   002:56                 |         -- -- -- -- |
#    SJU   015:09  Fairmont El San Juan Hote     787-791-1000      008:21      |-- -- -- -- -- -- -- |
#  2     1434  SJU  06:15   MCO  09:12   001:58   32M   002:57  *              |-- -- -- -- -- -- -- |
#  2     1033  MCO  11:10   SJU  14:06            32M   002:56                 |-- -- -- -- 22 -- -- |
#    SJU   015:09  Fairmont El San Juan Hote     787-791-1000      008:51      |-- -- -- -- -- --    |
#  3     1434  SJU  06:15   MCO  09:12   000:48   32M   002:57                 +---------------------+
#  3     2528  MCO  10:00   EWR  12:37            32M   002:37
# ...
#  1     0194  STI  20:09   EWR  23:59            32M   003:50                 |         -- 01 -- -- |
#    EWR   012:01  Renaissance EWR Airport       908-436-4600      009:53      |-- -- -- -- -- -- -- |
#  2     2603  EWR  13:00   SDQ  16:58   001:18   32M   003:58                 |-- -- -- -- -- -- -- |
#  2     2604  SDQ  18:16   EWR  22:13            32M   003:57                 |-- -- -- -- -- -- -- |
#    EWR   017:37  The Westin Jersey City Ne     201-626-2900      010:13      |-- -- -- -- -- --    |
#  3     1727  EWR  16:50   MCO  19:49            32M   002:59                 +---------------------+
#    MCO   012:01  Marriott Orlando Airport      407-851-9000      003:59
#  4     2528  MCO  08:50   EWR  11:37            32M   002:47
#                                                                  003:47
#                                                     ----------------------
# Credit: 021:19                                        021:19     027:52
# TAFB: 069:31
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2078  Check-In 15:50   Check-Out 11:52            4-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     1727  EWR  16:50   MCO  19:49            32M   002:59                 |=====================|
#    MCO   012:01  Marriott Orlando Airport      407-851-9000      004:14      |         31 -- -- -- |
#  2     0113  MCO  08:50   CUN  09:52   001:08   32M   002:02                 |-- -- -- -- -- -- -- |
#        0114  CUN  11:00   MCO  14:05   002:10   32M   002:05  *              |-- -- -- -- -- -- -- |
#  2     1586  MCO  16:15   BUF  19:02            32M   002:47                 |-- -- -- -- -- -- -- |
#    BUF   012:38  Aloft Buffalo Airport         716-626-1800      011:12      |-- -- -- -- -- --    |
#  3     0085  BUF  08:40   MCO  11:17   000:48   32M   002:37                 +---------------------+
#        1076  MCO  12:05   PVD  14:57   000:48   32M   002:52
#  3     1075  PVD  15:45   MCO  18:39            32M   002:54
#    MCO   013:11  Marriott Orlando Airport      407-851-9000      010:59
#  4     2528  MCO  08:50   EWR  11:37            32M   002:47
#                                                                  003:47
#                                                     ----------------------
# Credit: 021:03                                        021:03     030:12
# TAFB: 068:02
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2079  Check-In 18:10   Check-Out 16:46            4-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     2073  EWR  19:10   LAX  22:10            32S   006:00                 |=====================|
#    LAX   024:45  SONESTA REDONDO BEACH & M     310-318-8888      007:15      |         31 -- -- -- |
#  3     1574  LAX  23:55   EWR  08:34            32S   005:39                 |-- -- -- -- -- -- -- |
#    EWR   021:46  The Westin Jersey City Ne     201-626-2900      006:39      |-- -- -- -- -- -- -- |
#  4     1229  EWR  07:20   CUN  10:25   001:00   32M   004:05                 |-- -- -- -- -- -- -- |
#  4     1230  CUN  11:25   EWR  16:31            32M   004:06                 |-- -- -- -- -- --    |
#                                                                  010:11      +---------------------+
#                                                     ----------------------
# Credit: 020:10                                        019:50     024:05
# TAFB: 070:36
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2080  Check-In 19:55   Check-Out 16:35            4-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     1573  EWR  20:55   LAX  23:54            32S   005:59                 |=====================|
#    LAX   021:34  SONESTA REDONDO BEACH & M     310-318-8888      007:14      |         -- -- -- -- |
#  3     1574  LAX  22:28   EWR  06:55            32S   005:27                 |-- -- -- -- -- -- -- |
#    EWR   023:35  The Westin Jersey City Ne     201-626-2900      006:27      |-- -- -- -- -- -- -- |
#  4     1229  EWR  07:30   CUN  10:26   001:00   32M   003:56                 |-- -- -- -- -- -- -- |
#  4     1230  CUN  11:26   EWR  16:20            32M   003:54                 |-- -- 27 -- -- --    |
#                                                                  009:50      +---------------------+
#                                                     ----------------------
# Credit: 020:00                                        019:16     023:31
# TAFB: 068:40
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2081  Check-In 20:00   Check-Out 19:25            4-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     1003  EWR  21:00   SDQ  00:48            32M   003:48                 |=====================|
#    SDQ   025:02  Sheraton Santo Domingo        809 221 6666      005:03      |         -- -- -- -- |
#  3     1004  SDQ  02:50   EWR  06:50            32M   004:00                 |-- -- -- -- -- 09 -- |
#    EWR   024:43  The Westin Jersey City Ne     201-626-2900      005:00      |-- -- -- -- -- 16 -- |
#  4     0345  EWR  08:33   AUA  13:15   001:00   32M   004:42                 |-- -- -- -- -- -- -- |
#  4 DH  0346  AUA  14:15   EWR  19:10            32M   000:00                 |-- -- -- -- -- --    |
#                                                                  011:37      +---------------------+
#                                                     ----------------------
# Credit: 020:24                                        012:30     021:40
# TAFB: 071:25
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2082  Check-In 20:15   Check-Out 22:13            4-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     0273  EWR  21:15   LAX  00:15            32S   006:00                 |=====================|
#    LAX   019:35  SONESTA REDONDO BEACH & M     310-318-8888      007:15      |         -- -- -- -- |
#  2     0888  LAX  20:50   BOS  05:22            3NS   005:32                 |-- -- 06 -- -- -- -- |
#    BOS   013:04  Boston Park Plaza             617-426-2000      006:32      |-- -- -- -- -- -- -- |
#  3     0921  BOS  19:26   SJU  23:27            32M   004:01                 |-- -- -- -- -- -- -- |
#    SJU   013:58  Sheraton Puerto Rico Hote     787 993 3500      005:01      |-- -- -- -- -- --    |
#  4     0934  SJU  14:25   MCO  17:23   001:52   32M   002:58  *              +---------------------+
#  4     0828  MCO  19:15   EWR  21:58            32M   002:43
#                                                                  008:33
#                                                     ----------------------
# Credit: 021:14                                        021:14     027:21
# TAFB: 073:58
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2083  Check-In 07:33   Check-Out 22:13            5-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     0345  EWR  08:33   AUA  13:15            32M   004:42                 |=====================|
#    AUA   023:30  Renaissance Aruba Resort      011 2975836000    005:57      |         -- -- -- -- |
#  2     0346  AUA  13:45   EWR  18:38   002:02   32M   004:53                 |-- -- -- -- -- -- -- |
#  2     1827  EWR  20:40   MCO  23:23            32M   002:43                 |-- -- -- -- -- -- -- |
#    MCO   014:25  Marriott Orlando Airport      407-851-9000      010:38      |-- -- -- -- -- 23 -- |
#  3     0767  MCO  14:48   PSE  17:41   001:09   32M   002:53                 |-- -- -- -- -- --    |
#  3     0768  PSE  18:50   MCO  21:54            32M   003:04                 +---------------------+
#    MCO   013:21  Marriott Orlando Airport      407-851-9000      008:06
#  4     1076  MCO  12:15   PVD  14:58   000:47   32M   002:43
#        1075  PVD  15:45   MCO  18:38   000:57   32M   002:53  *
#  4     1433  MCO  19:35   SJU  22:29            32M   002:54
#    SJU   014:56  Sheraton Puerto Rico Hote     787 993 3500      011:14
#  5     0934  SJU  14:25   MCO  17:23   001:52   32M   002:58  *
#  5     0828  MCO  19:15   EWR  21:58            32M   002:43
#                                                                  008:33
#                                                     ----------------------
# Credit: 032:26                                        032:26     044:28
# TAFB: 110:40
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2084  Check-In 08:00   Check-Out 23:50            5-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     1015  EWR  09:00   PUJ  13:01   001:00   32M   004:01                 |=====================|
#  1     1016  PUJ  14:01   EWR  18:04            32M   004:03                 |         -- -- -- -- |
#    EWR   012:26  Renaissance EWR Airport       908-436-4600      010:19      |-- -- -- -- -- -- -- |
#  2     1229  EWR  07:30   CUN  10:26   001:00   32M   003:56                 |-- -- -- -- -- -- -- |
#        1230  CUN  11:26   EWR  16:20   001:30   32M   003:54  *              |-- -- -- -- -- -- -- |
#  2 DH  LIMO  EWR  17:50   JFK  19:20                  000:00                 |-- 26 -- -- -- --    |
#    JFK   012:40  Hilton JFK                    718-659-0200      012:50      +---------------------+
#  3     0411  JFK  09:00   LAS  11:37            3N1   005:37
#    LAS   033:00  Park MGM Las Vegas                              006:37
#  5     0608  LAS  21:37   FLL  05:15            321   004:38
#    FLL   014:25  Hyatt Place Fort Lauderda     954-922-0436      005:38
#  5     0706  FLL  20:40   EWR  23:35            32M   002:55
#                                                                  003:55
#                                                     ----------------------
# Credit: 031:57                                        029:04     039:19
# TAFB: 111:50
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2085  Check-In 12:00   Check-Out 07:05            5-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     2603  EWR  13:00   SDQ  16:58   001:18   32M   003:58                 |=====================|
#  1     2604  SDQ  18:16   EWR  22:13            32M   003:57                 |         -- -- -- -- |
#    EWR   012:02  Renaissance EWR Airport       908-436-4600      010:28      |-- 05 -- -- -- -- -- |
#  2 DH  0995  EWR  11:00   SXM  15:07   001:10   32M   000:00                 |-- -- -- -- -- -- -- |
#  2     0096  SXM  16:17   EWR  20:39            32M   004:22                 |-- -- -- -- -- -- -- |
#    EWR   023:21  The Westin Jersey City Ne     201-626-2900      010:24      |-- -- -- -- -- --    |
#  3     1003  EWR  21:00   SDQ  00:48            32M   003:48                 +---------------------+
#    SDQ   025:02  Sheraton Santo Domingo        809 221 6666      004:48
#  5     1004  SDQ  02:50   EWR  06:50            32M   004:00
#                                                                  005:00
#                                                     ----------------------
# Credit: 026:01                                        020:05     030:40
# TAFB: 091:05
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2086  Check-In 14:14   Check-Out 07:05            5-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     1493  EWR  15:14   STI  18:59   001:00   32M   003:45                 |=====================|
#  1     0194  STI  19:59   EWR  23:42            32M   003:43                 |         -- -- -- -- |
#    EWR   014:32  Renaissance EWR Airport       908-436-4600      009:43      |-- -- -- -- -- -- -- |
#  2     1493  EWR  15:14   STI  18:59   001:00   32M   003:45                 |-- -- -- -- -- -- 17 |
#  2     0194  STI  19:59   EWR  23:42            32M   003:43                 |-- -- -- -- -- -- 24 |
#    EWR   020:18  The Westin Jersey City Ne     201-626-2900      009:28      |-- 26 -- -- -- --    |
#  3     1003  EWR  21:00   SDQ  00:48            32M   003:48                 +---------------------+
#    SDQ   025:02  Sheraton Santo Domingo        809 221 6666      004:48
#  5     1004  SDQ  02:50   EWR  06:50            32M   004:00
#                                                                  005:00
#                                                     ----------------------
# Credit: 025:23                                        022:44     028:59
# TAFB: 088:51
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# E2087  Check-In 14:21   Check-Out 07:05            5-Day                     SEP 2022
#                                                                              +---------------------+
# Day    Flt   Dep  Local   Arr  Local   Turn     Eqp   Block      Duty        | S  M  T  W  T  F  S |
#  1     1493  EWR  15:21   STI  19:09   001:00   32M   003:48                 |=====================|
#  1     0194  STI  20:09   EWR  23:59            32M   003:50                 |         -- -- -- -- |
#    EWR   014:15  Renaissance EWR Airport       908-436-4600      009:53      |-- -- 06 -- -- -- -- |
#  2     1493  EWR  15:14   STI  18:59   001:00   32M   003:45                 |-- -- -- -- -- -- -- |
#  2     0194  STI  19:59   EWR  23:42            32M   003:43                 |-- -- -- -- -- -- -- |
#    EWR   020:18  The Westin Jersey City Ne     201-626-2900      009:28      |-- -- -- -- -- --    |
#  3     1003  EWR  21:00   SDQ  00:48            32M   003:48                 +---------------------+
#    SDQ   025:02  Sheraton Santo Domingo        809 221 6666      004:48
#  5     1004  SDQ  02:50   EWR  06:50            32M   004:00
#                                                                  005:00
#                                                     ----------------------
# Credit: 025:21                                        022:54     029:09
# TAFB: 088:44
# Crew Comp:  1 CA, 1 FO
# ----------------------------------------------------------------------------------------------------
# END

# %% [markdown]
# Here we're concerned with extracting the flight table from the data for display.

# %%
# Extract the flight details using regular expressions
flight_data = re.findall(r'(\d)?\s+(\d+)\s+(\w{3})\s{2}(\d{2}:\d{2})\s{3}(\w{3})\s{2}(\d{2}:\d{2})\s*(\d{3}:\d{2})?\s*(\w{3})\s{3}(\d{3}:\d{2})', raw_data) # raw data is a simple dataset stored in confidential.py

columns = ['Day', 'Flt', 'Dep', 'Local_Dep', 'Arr', 'Local_Arr', 'Turn', 'Eqp', 'Block']
flight_table = pd.DataFrame(flight_data, columns=columns)
print(flight_table)
# Out:
#   Day   Flt  Dep Local_Dep  Arr Local_Arr    Turn  Eqp   Block
# 0   1  1015  EWR     09:00  PUJ     13:01  001:00  32M  004:01
# 1   1  1016  PUJ     14:01  EWR     18:04          32M  004:03
# 2   2  1229  EWR     07:30  CUN     10:26  001:00  32M  003:56
# 3   2  1230  CUN     11:26  EWR     16:20          32M  003:54
# 4   3  0573  EWR     07:00  TPA     09:46          32M  002:46
# 5   4  2274  TPA     08:50  EWR     11:31          32M  002:41

# %%
# Extract other variables of interest

## From the top line pull the pairing code and the number of days of the pairing

p_code = re.findall(r'[A-Z]\d+', raw_data)
p_code = p_code[0]
print(p_code)

n_days = re.findall(r'(\d+)-Day', raw_data)
n_days = int(n_days[0])
print(n_days)

## Near the bottom pull both the total credit and sum of the block times and use it to calculate the soft time. Plus record time away from base

credit_sum = re.findall(r'Credit:\s(\d{3}:\d{2})', raw_data)
credit_sum = credit_sum[0]
hours, minutes = map(int, credit_sum.split(':'))
credit_sum = timedelta(hours=hours, minutes=minutes)
print(credit_sum)

block_sum = re.findall(r'\w\s{40}(\d{3}:\d{2})', raw_data)
block_sum = block_sum[0]
hours, minutes = map(int, block_sum.split(':'))
block_sum = timedelta(hours=hours, minutes=minutes)
print(block_sum)

softtime = credit_sum - block_sum
print(softtime)

tafb = re.findall(r'TAFB:\s(\d{3}:\d{2})', raw_data)
tafb = tafb[0]
hours, minutes = map(int, tafb.split(':'))
tafb = timedelta(hours=hours, minutes=minutes)
print(tafb)

## Here, we concern ourselves with dates. We want the dates in the calendar on the right to match with the month and year above the calendar.

my = re.findall(r'[A-Z]{3}\s\d{4}', raw_data)
my = datetime.strptime(my[0],"%b %Y")
print(my)

d = list()
d_lines = re.findall(r'\|.*\|', raw_data)
for week in d_lines:
    d_strs = re.findall(r'\d+', week)
    for d_str in d_strs:
        d.append(d_str)

d = [int(num) for num in d]
mdy = [my + timedelta(days=item-1) for item in d]
for date in mdy:
    print(date)

## Further, we want check in and checkout times to be associated with these dates.

checkin = re.findall(r'Check-In\s(\d{2}:\d{2})', raw_data)
checkin = datetime.strptime(checkin[0],"%H:%M")
checkins = list()
for date in mdy:
    checkin_datetime = datetime.combine(date.date(), checkin.time())
    checkins.append(checkin_datetime)
print(checkins)

checkout = re.findall(r'Check-Out\s(\d{2}:\d{2})', raw_data)
checkout = datetime.strptime(checkout[0],"%H:%M")
checkouts = list()
for date in mdy:
    date = date + timedelta(days = n_days - 1)
    checkout_datetime = datetime.combine(date.date(), checkout.time())
    checkouts.append(checkout_datetime)
print(checkouts)

checkinouts = []
for item1, item2 in zip(checkins, checkouts):
    checkinouts.append((item1, item2))
print(checkinouts[1])
# Out:
# E2071
# 4
# 21:39:00
# 21:21:00
# 0:18:00
# 3 days, 3:46:00
# 2022-09-01 00:00:00
# 2022-09-10 00:00:00
# 2022-09-11 00:00:00
# 2022-09-17 00:00:00
# 2022-09-19 00:00:00
# 2022-09-20 00:00:00
# 2022-09-23 00:00:00
# 2022-09-27 00:00:00
# [datetime.datetime(2022, 9, 10, 8, 0), datetime.datetime(2022, 9, 11, 8, 0), datetime.datetime(2022, 9, 17, 8, 0), datetime.datetime(2022, 9, 19, 8, 0), datetime.datetime(2022, 9, 20, 8, 0), datetime.datetime(2022, 9, 23, 8, 0), datetime.datetime(2022, 9, 27, 8, 0)]
# [datetime.datetime(2022, 9, 13, 11, 46), datetime.datetime(2022, 9, 14, 11, 46), datetime.datetime(2022, 9, 20, 11, 46), datetime.datetime(2022, 9, 22, 11, 46), datetime.datetime(2022, 9, 23, 11, 46), datetime.datetime(2022, 9, 26, 11, 46), datetime.datetime(2022, 9, 30, 11, 46)]
# (datetime.datetime(2022, 9, 11, 8, 0), datetime.datetime(2022, 9, 14, 11, 46))

# %%
#print(file_contents)

pairings = file_contents.split('----------------------------------------------------------------------------------------------------\n')
del pairings[0]
del pairings[-1]
#pairings_list = list()

table_columns = ['p_code', 'n_days', 'checkin', 'checkout', 'credit_sum', 'block_sum', 'softtime','flight_data']
table_data = pd.DataFrame(columns=table_columns)

for pairing in pairings:
    
    flight_data = re.findall(r'(\d)?\s+(\d+)\s+(\w{3})\s{2}(\d{2}:\d{2})\s{3}(\w{3})\s{2}(\d{2}:\d{2})\s*(\d{3}:\d{2})?\s*(\w{3})\s{3}(\d{3}:\d{2})', pairing) # raw data is a simple dataset stored in confidential.py

    columns = ['Day', 'Flt', 'Dep', 'Local_Dep', 'Arr', 'Local_Arr', 'Turn', 'Eqp', 'Block']
    flight_table = pd.DataFrame(flight_data, columns=columns)

    # Extract other variables of interest

    ## From the top line pull the pairing code and the number of days of the pairing

    p_code = re.findall(r'[A-Z]\d+', pairing)
    p_code = p_code[0]

    n_days = re.findall(r'(\d+)-Day', pairing)
    n_days = int(n_days[0])

    ## Near the bottom pull both the total credit and sum of the block times and use it to calculate the soft time. Plus record time away from base

    credit_sum = re.findall(r'Credit:\s(\d{3}:\d{2})', pairing)
    credit_sum = credit_sum[0]
    hours, minutes = map(int, credit_sum.split(':'))
    credit_sum = timedelta(hours=hours, minutes=minutes)

    block_sum = re.findall(r'\w\s{40}(\d{3}:\d{2})', pairing)
    block_sum = block_sum[0]
    hours, minutes = map(int, block_sum.split(':'))
    block_sum = timedelta(hours=hours, minutes=minutes)

    softtime = credit_sum - block_sum

    tafb = re.findall(r'TAFB:\s(\d{3}:\d{2})', pairing)
    tafb = tafb[0]
    hours, minutes = map(int, tafb.split(':'))
    tafb = timedelta(hours=hours, minutes=minutes)

    ## Here, we concern ourselves with dates. We want the dates in the calendar on the right to match with the month and year above the calendar.

    my = re.findall(r'[A-Z]{3}\s\d{4}', pairing)
    my = datetime.strptime(my[0],"%b %Y")

    d = list()
    d_lines = re.findall(r'\|.*\|', pairing)
    for week in d_lines:
        d_strs = re.findall(r'\d+', week)
        for d_str in d_strs:
            d.append(d_str)

    print(d_lines)

    d = [int(num) for num in d]
    mdy = [my + timedelta(days=item-1) for item in d]

    ## Further, we want check in and checkout times to be associated with these dates.

    checkin = re.findall(r'Check-In\s(\d{2}:\d{2})', pairing)
    checkin = datetime.strptime(checkin[0],"%H:%M")
    checkins = list()
    for date in mdy:
        checkin_datetime = datetime.combine(date.date(), checkin.time())
        checkins.append(checkin_datetime)

    checkout = re.findall(r'Check-Out\s(\d{2}:\d{2})', pairing)
    checkout = datetime.strptime(checkout[0],"%H:%M")
    checkouts = list()
    for date in mdy:
        date = date + timedelta(days = n_days - 1)
        checkout_datetime = datetime.combine(date.date(), checkout.time())
        checkouts.append(checkout_datetime)

    ## Now all that remains is to make our table_data with all pairings. But because we want to filter by dates, we actually make an observation for each date a pairing is offered as well.

    checkinouts = []
    for item1, item2 in zip(checkins, checkouts):
        checkinouts.append((item1, item2))
    
    for checkinout in checkinouts:
        checkin, checkout = checkinout
        obs = pd.DataFrame([[p_code, n_days, checkin, checkout, credit_sum, block_sum, softtime, flight_data]], columns = table_columns)
        table_data = pd.concat([table_data, obs], ignore_index=True)

print(table_data)    

#for pairing in pairings:
#print(pairings)
# Out:
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- 03 |', '|04 -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- 07 08 09 -- |', '|11 12 -- 14 -- 16 -- |', '|18 19 20 21 22 23 -- |', '|25 26 27 -- 29 30    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- 10 |', '|-- -- -- -- -- -- 17 |', '|-- -- -- -- -- -- 24 |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         31 01 02 -- |', '|-- -- 06 -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- 06 -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         31 01 02 03 |', '|04 05 -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         31 -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- 19 -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- 03 |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- 01 -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- 03 |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- 12 -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|25 -- -- -- 29 --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- 22 -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- 01 -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|18 -- -- -- -- -- -- |', '|25 -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         31 -- -- 03 |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         31 -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- 03 |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- 12 -- -- -- -- -- |', '|-- -- -- -- -- 23 -- |', '|-- -- -- -- -- 30    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- 08 09 -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- 12 -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- 02 -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- 06 -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- 16 -- |', '|-- -- -- -- 22 23 -- |', '|-- -- -- -- -- 30    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|04 -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- 24 |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- 30    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- 09 -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- 14 -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         31 -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|04 -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- 05 -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- 15 -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- 29 --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- 21 -- -- -- |', '|-- -- -- 28 -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- 29 --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- 01 -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- 02 -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- 21 -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         31 01 02 03 |', '|04 05 -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|11 -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- 22 -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- 12 -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- 16 -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- 08 -- -- |', '|-- -- -- -- 15 -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- 26 -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- 29 --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- 26 -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- 03 |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- 24 |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- 02 -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|04 -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         31 -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- 01 -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- 09 -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- 08 -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|04 -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- 07 -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- 06 -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- 14 -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- 29 --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         31 -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|18 -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- 29 --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- 15 -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- 23 -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- 27 -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- 22 -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- 10 |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- 06 -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|11 -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- 10 |', '|11 -- -- -- -- -- 17 |', '|-- 19 20 -- -- 23 -- |', '|-- -- 27 -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- 03 |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- 28 -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         31 -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|04 -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- 13 -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- 01 -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         31 -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         31 -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- 27 -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- 09 -- |', '|-- -- -- -- -- 16 -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- 06 -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- 23 -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- 26 -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- 05 -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- 17 |', '|-- -- -- -- -- -- 24 |', '|-- 26 -- -- -- --    |']
# ['| S  M  T  W  T  F  S |', '|=====================|', '|         -- -- -- -- |', '|-- -- 06 -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- -- -- |', '|-- -- -- -- -- --    |']
#     p_code n_days             checkin            checkout      credit_sum  \
# 0    E2001      1 2022-09-03 05:14:00 2022-09-03 13:50:00 0 days 06:14:00
# 1    E2001      1 2022-09-04 05:14:00 2022-09-04 13:50:00 0 days 06:14:00
# 2    E2002      1 2022-09-07 05:59:00 2022-09-07 14:09:00 0 days 05:52:00
# 3    E2002      1 2022-09-08 05:59:00 2022-09-08 14:09:00 0 days 05:52:00
# 4    E2002      1 2022-09-09 05:59:00 2022-09-09 14:09:00 0 days 05:52:00
# ..     ...    ...                 ...                 ...             ...
# 137  E2085      5 2022-09-05 12:00:00 2022-09-09 07:05:00 1 days 02:01:00
# 138  E2086      5 2022-09-17 14:14:00 2022-09-21 07:05:00 1 days 01:23:00
# 139  E2086      5 2022-09-24 14:14:00 2022-09-28 07:05:00 1 days 01:23:00
# 140  E2086      5 2022-09-26 14:14:00 2022-09-30 07:05:00 1 days 01:23:00
# 141  E2087      5 2022-09-06 14:21:00 2022-09-10 07:05:00 1 days 01:21:00
#
#           block_sum        softtime  \
# 0   0 days 06:14:00 0 days 00:00:00
# 1   0 days 06:14:00 0 days 00:00:00
# 2   0 days 05:52:00 0 days 00:00:00
# 3   0 days 05:52:00 0 days 00:00:00
# 4   0 days 05:52:00 0 days 00:00:00
# ..              ...             ...
# 137 0 days 20:05:00 0 days 05:56:00
# 138 0 days 22:44:00 0 days 02:39:00
# 139 0 days 22:44:00 0 days 02:39:00
# 140 0 days 22:44:00 0 days 02:39:00
# 141 0 days 22:54:00 0 days 02:27:00
#
#                                            flight_data
# 0    [(1, 2295, EWR, 06:14, MIA, 09:18, 001:07, 32M...
# 1    [(1, 2295, EWR, 06:14, MIA, 09:18, 001:07, 32M...
# 2    [(1, 1711, EWR, 06:59, RSW, 09:57, 001:03, 32M...
# 3    [(1, 1711, EWR, 06:59, RSW, 09:57, 001:03, 32M...
# 4    [(1, 1711, EWR, 06:59, RSW, 09:57, 001:03, 32M...
# ..                                                 ...
# 137  [(1, 2603, EWR, 13:00, SDQ, 16:58, 001:18, 32M...
# 138  [(1, 1493, EWR, 15:14, STI, 18:59, 001:00, 32M...
# 139  [(1, 1493, EWR, 15:14, STI, 18:59, 001:00, 32M...
# 140  [(1, 1493, EWR, 15:14, STI, 18:59, 001:00, 32M...
# 141  [(1, 1493, EWR, 15:21, STI, 19:09, 001:00, 32M...
#
# [142 rows x 8 columns]
